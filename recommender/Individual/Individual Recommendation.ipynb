# %% [markdown]
# # A humble attempt to Individual Playlist Recommendation
# We will begin by importing tracks dataset to perform apriori analysis by calculation support and confidence for each track/artist

# %%
import pandas as pd


preprocessed_dataset_folder = "../dataset/spotify_million_playlist_dataset/subset"

tracks_df = pd.read_csv(preprocessed_dataset_folder+"/tracks.csv")
display(tracks_df)
# Out:
#         Unnamed: 0 playlist  pid                                  track_name  \
# 0            54796    CHiLl  819                                      Jungle
# 1            54787    CHiLl  819                                  Fresh Eyes
# 2            54794    CHiLl  819                                 Love Inside
# 3            54797    CHiLl  819     Juke Jam (feat. Justin Bieber & Towkio)
# 4            54788    CHiLl  819  We Don't Talk Anymore (feat. Selena Gomez)
# ...            ...      ...  ...                                         ...
# 334482       11726       🤤🤤  180                             What's My Name?
# 334483       11727       🤤🤤  180                    Only Girl (In The World)
# 334484       11728       🤤🤤  180                         Where Have You Been
# 334485       11729       🤤🤤  180                                   Right Now
# 334486       11730       🤤🤤  180      Come Out And Play (Keep ‘Em Separated)
#
# ...

# %%
tracks_df.value_counts()
# Out:
# Unnamed: 0  playlist    pid   track_name                                                      artist_name                         album_name                             track_pos
# 0           Throwbacks  0     Lose Control (feat. Ciara & Fat Man Scoop)                      Missy Elliott                       The Cookbook                           0            1
# 222978      Country     3342  Night's On Fire                                                 David Nail                          Fighter                                53           1
# 222996      Country     3342  (This Ain’t No) Drunk Dial                                      A Thousand Horses                   Southernality                          71           1
# 222995      Country     3342  Smoke                                                           A Thousand Horses                   Southernality                          70           1
# ...
